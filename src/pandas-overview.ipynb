# %% [markdown]
# # Pandas Overview

# %% [markdown]
# The purpose of this notebook is to offer an overview of pandas features via a concrete data analysis
# Dataset details : https://www.kaggle.com/datasets/murderaccountability/homicide-reports

# %% [markdown]
# ### Dependencies

# %%
# %matplotlib inline
from IPython.display import display
import numpy as np
import pandas as pd 
import re
import matplotlib.pylab as plt
import seaborn as sns

# %% [markdown]
# ### Pandas configuration

# %%
#misc
plt.style.use('ggplot')

# pandas
pd.options.display.min_rows = 20
pd.options.display.max_columns = 200
pd.options.display.max_colwidth = 25
pd.options.display.expand_frame_repr = 100
pd.options.display.max_rows = 50 # None = no limitation
pd.options.display.max_seq_items = 50 # Max length of printed sequence
pd.options.display.precision = 4
pd.options.display.show_dimensions = False
pd.__version__
# Out:
# '1.5.1'

# %% [markdown]
# ### Helpers

# %%
def clean_title(title):
    title = re.sub('[-_ ]', ' ', title)
    return ''.join(word.capitalize() for word in title.split(' '))

# %%
def millify(num):
    return f"{num:,}"

# %%
def get_var(df, var_name):
    globals()[var_name] = df
    return df

# %% [markdown]
# ### Data import

# %%
# read raw data
crimes = pd.read_csv(
    'homicide_reports_1980-2014.zip',
    low_memory=False
) 
millify(crimes.memory_usage().sum())
# Out:
# '122,583,296'

# %% [markdown]
# ### Data understanding

# %%
crimes.shape
# Out:
# (638454, 24)

# %%
# display 5 lines : head(5), tail(5), sample(5)
crimes.sample(5)
# Out:
#         Record ID Agency Code      Agency Name       Agency Type         City  \
# 486182     486183     FL00612            Davie  Municipal Police      Broward
# 610070     610071     WI06500  Walworth County           Sheriff     Walworth
# 625440     625441     CA01942      Los Angeles  Municipal Police  Los Angeles
# 451992     451993     CA03404       Sacramento  Municipal Police   Sacramento
# 545927     545928     PAPPD00       Pittsburgh  Municipal Police    Allegheny
#
#                State  Year     Month  Incident                Crime Type  \
# 486182       Florida  2005     March       768    Murder or Manslaughter
# 610070     Wisconsin  2013   October         1  Manslaughter by Negli...
# 625440    California  2014  November        19    Murder or Manslaughter
# 451992    California  2003  December         5    Murder or Manslaughter
# 545927  Pennsylvania  2008   October         1    Murder or Manslaughter
#
#        Crime Solved Victim Sex  Victim Age             Victim Race  \
# 486182          Yes       Male           1                   White
# 610070          Yes     Female          40                   White
# 625440          Yes       Male          29                   White
# 451992           No       Male          43  Asian/Pacific Islander
# 545927           No       Male          43                   Black
#
#        Victim Ethnicity Perpetrator Sex Perpetrator Age Perpetrator Race  \
# 486182          Unknown            Male              24            White
# 610070          Unknown            Male              50            White
# 625440         Hispanic            Male              41            White
# 451992     Not Hispanic         Unknown               0          Unknown
# 545927     Not Hispanic         Unknown               0          Unknown
#
#        Perpetrator Ethnicity Relationship        Weapon  Victim Count  \
# 486182               Unknown          Son       Unknown             0
# 610070               Unknown     Stranger       Unknown             0
# 625440              Hispanic      Unknown  Blunt Object             0
# 451992               Unknown      Unknown       Handgun             0
# 545927               Unknown      Unknown       Unknown             0
#
#         Perpetrator Count Record Source
# 486182                  0          FOIA
# 610070                  0           FBI
# 625440                  1           FBI
# 451992                  0           FBI
# 545927                  0           FBI

# %%
crimes.dtypes
# Out:
# Record ID                 int64
# Agency Code              object
# Agency Name              object
# Agency Type              object
# City                     object
# State                    object
# Year                      int64
# Month                    object
# Incident                  int64
# Crime Type               object
# Crime Solved             object
# Victim Sex               object
# Victim Age                int64
# Victim Race              object
# Victim Ethnicity         object
# Perpetrator Sex          object
# Perpetrator Age          object
# Perpetrator Race         object
# Perpetrator Ethnicity    object
# Relationship             object
# Weapon                   object
# Victim Count              int64
# Perpetrator Count         int64
# Record Source            object
# dtype: object

# %%
crimes.columns
# Out:
# Index(['Record ID', 'Agency Code', 'Agency Name', 'Agency Type', 'City',
#        'State', 'Year', 'Month', 'Incident', 'Crime Type', 'Crime Solved',
#        'Victim Sex', 'Victim Age', 'Victim Race', 'Victim Ethnicity',
#        'Perpetrator Sex', 'Perpetrator Age', 'Perpetrator Race',
#        'Perpetrator Ethnicity', 'Relationship', 'Weapon', 'Victim Count',
#        'Perpetrator Count', 'Record Source'],
#       dtype='object')

# %%
crimes.index
# Out:
# RangeIndex(start=0, stop=638454, step=1)

# %%
crimes.describe()
# Out:
#          Record ID         Year     Incident   Victim Age  Victim Count  \
# count  638454.0000  638454.0000  638454.0000  638454.0000   638454.0000
# mean   319227.5000    1995.8011      22.9679      35.0335        0.1233
# std    184305.9387       9.9277      92.1498      41.6283        0.5377
# min         1.0000    1980.0000       0.0000       0.0000        0.0000
# 25%    159614.2500    1987.0000       1.0000      22.0000        0.0000
# 50%    319227.5000    1995.0000       2.0000      30.0000        0.0000
# 75%    478840.7500    2004.0000      10.0000      42.0000        0.0000
# max    638454.0000    2014.0000     999.0000     998.0000       10.0000
#
#        Perpetrator Count
# count        638454.0000
# mean              0.1852
# std               0.5855
# min               0.0000
# 25%               0.0000
# 50%               0.0000
# 75%               0.0000
# max              10.0000

# %% [markdown]
# ### Data tweaking

# %%
# tweek data
def tweak_crimes(df_):

    return (df_
        .rename(columns=clean_title)
        .assign(
            PerpetratorAge=lambda df_ : pd.to_numeric(df_['PerpetratorAge'], errors ='coerce').fillna(0),
            CrimeDate=pd.to_datetime(df_['Year'].astype(str) + ' ' + df_['Month'].astype(str) + ' 1', format="%Y %B %d")                
        )
        .astype({
            'CrimeSolved' : 'bool',
            **{ name : 'category' for name in [
                'AgencyCode', 
                'AgencyName', 
                'AgencyType',
                'City', 
                'State', 
                'CrimeType',
                'VictimSex',
                'VictimRace',
                'VictimEthnicity',
                'PerpetratorSex',
                'PerpetratorRace',
                'PerpetratorEthnicity',
                'Relationship',
                'Weapon',
                'RecordSource'                            
            ]},
            **{ name : np.uint8 for name in [
                'Incident',
                'VictimAge',
                'VictimCount',
                'PerpetratorAge',
                'PerpetratorCount'
            ]}
        })
        .set_index("RecordId")
        .drop(columns=['Month', 'Year'])     
    #     .pipe(lambda df: display(df) or df )
    #     .pipe(get_var, 'temp')
)

crimes = tweak_crimes(crimes)

# %% [markdown]
# ### Data display

# %%
# memory consumption
millify(crimes.memory_usage(deep=True).sum())
# Out:
# '27,669,047'

# %%
# types and memory consumption
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 638454 entries, 1 to 638454
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   AgencyCode            638454 non-null  category
#  1   AgencyName            638454 non-null  category
#  2   AgencyType            638454 non-null  category
#  3   City                  638454 non-null  category
#  4   State                 638454 non-null  category
#  5   Incident              638454 non-null  uint8
#  6   CrimeType             638454 non-null  category
#  7   CrimeSolved           638454 non-null  bool
#  8   VictimSex             638454 non-null  category
#  9   VictimAge             638454 non-null  uint8
#  10  VictimRace            638454 non-null  category
#  11  VictimEthnicity       638454 non-null  category
#  12  PerpetratorSex        638454 non-null  category
#  13  PerpetratorAge        638454 non-null  uint8
#  14  PerpetratorRace       638454 non-null  category
#  15  PerpetratorEthnicity  638454 non-null  category
#  16  Relationship          638454 non-null  category
#  17  Weapon                638454 non-null  category
#  18  VictimCount           638454 non-null  uint8
#  19  PerpetratorCount      638454 non-null  uint8
#  20  RecordSource          638454 non-null  category
#  21  CrimeDate             638454 non-null  datetime64[ns]
# dtypes: bool(1), category(15), datetime64[ns](1), uint8(5)
# memory usage: 25.1 MB

# %% [markdown]
# ### Data aggregation

# %%
minVictims=0

(crimes
 
     # filtering (could use query, where, loc, pipe, mask)
    .query('VictimSex != "Unknown"')    
#     .where(lambda x: x['VictimSex'].ne('Unknown'))
#     .loc[lambda x: x['VictimSex'].ne('Unknown')]
#     .pipe(lambda x: x[x['VictimSex'].ne('Unknown')]) 
#     .mask(lambda x: x['VictimSex'].eq('Unknown')) 
 
    
     # grouping data by year, ...
    .groupby([
        pd.Grouper(key="CrimeDate", freq="Y"), 
        'State',
        'VictimSex' 
    ] )
 
    # custom aggregations
    .agg(         
         TotalVictims = ('VictimCount', 'sum'),
         AvgVictimAge = ('VictimAge', lambda serie : serie.mean()),
         AvgPerpetratorAge = ('PerpetratorAge', 'mean'),
    )

     # filtering
     .query('TotalVictims > @minVictims')
     .dropna()
 
     # unpivot data, ie move to columns (could use melt)
     .unstack('VictimSex') 
            
)
# Out:
#                           TotalVictims        AvgVictimAge           \
# VictimSex                       Female   Male       Female     Male
# CrimeDate  State
# 1980-12-31 Alabama                17.0   25.0      38.7252  36.8455
#            Alaska                  4.0    2.0      35.8571  29.3030
#            Arizona                 9.0   13.0      39.1842  33.5324
#            Arkansas                9.0    9.0      29.5484  35.4605
#            California            121.0  201.0      34.5285  33.5100
#            Colorado                3.0   15.0      37.0000  33.6838
#            Connecticut             2.0    4.0      37.3143  35.4553
#            Delaware                4.0    4.0      29.4545  32.3939
#            Florida                44.0  104.0      36.3051  36.5209
#            Georgia                10.0   14.0      35.0367  36.5574
# ...                                ...    ...          ...      ...
# 2014-12-31 South Carolina         23.0   47.0      45.1282  33.5814
#            South Dakota            4.0    2.0      44.1111  35.5455
#            Tennessee               7.0   35.0      35.3733  33.8702
#            Texas                  86.0  110.0      37.8506  34.6084
#            Utah                   44.0   14.0      30.6667  30.2564
#            Vermont                 NaN    4.0          NaN  35.1250
#            Virginia               39.0   21.0      42.1250  34.4514
#            Washington             20.0   15.0      31.8421  36.6190
#            West Virginia           6.0    8.0      37.4783  50.6471
#            Wisconsin               6.0   10.0      33.0227  33.2126
#
#                           AvgPerpetratorAge
# VictimSex                            Female     Male
# CrimeDate  State
# 1980-12-31 Alabama                  30.8397  30.3822
#            Alaska                   24.6429  26.2727
#            Arizona                  25.0263  22.4213
#            Arkansas                 24.8065  31.2632
#            California               21.0385  17.6040
#            Colorado                 19.0000  19.9412
#            Connecticut              24.8286  22.0650
#            Delaware                 23.3636  21.6970
#            Florida                  21.8550  21.0606
#            Georgia                  24.6239  25.3634
# ...                                     ...      ...
# 2014-12-31 South Carolina           35.2949  23.7907
#            South Dakota             41.7778  29.5455
#            Tennessee                34.4267  22.2596
#            Texas                    31.6220  22.0622
#            Utah                     37.8182  28.9487
#            Vermont                      NaN  51.3750
#            Virginia                 35.8125  23.7588
#            Washington               32.8947  29.9320
#            West Virginia            39.9565  32.8235
#            Wisconsin                33.4545  23.0236

# %%
(crimes
    .groupby(
        pd.Grouper(key="CrimeDate", freq="M"), 
    )
    .agg(
        VictimsSum = ('VictimCount', 'sum'),
    ) 
    .assign(
        VictimsChange = lambda x : x['VictimsSum'].astype(int).pct_change(),
        VictimsDiff = lambda x : x['VictimsSum'].astype(float).diff()        
    )
    
    .style
        .format({'VictimsChange' : '{:.2f}'}, na_rep='N/A',precision=0)
        .bar(subset=['VictimsChange'], align=0, cmap="bwr", height=50)
        .background_gradient(subset=['VictimsSum'], cmap='Reds')
)
# Out:
# <style type="text/css">
# #T_af8bf_row0_col0, #T_af8bf_row14_col0, #T_af8bf_row26_col0, #T_af8bf_row37_col0, #T_af8bf_row312_col0 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_af8bf_row0_col1, #T_af8bf_row22_col1, #T_af8bf_row219_col1, #T_af8bf_row303_col1 {
#   width: 10em;
# }
# #T_af8bf_row1_col0, #T_af8bf_row21_col0, #T_af8bf_row22_col0, #T_af8bf_row45_col0, #T_af8bf_row73_col0, #T_af8bf_row93_col0, #T_af8bf_row114_col0, #T_af8bf_row119_col0, #T_af8bf_row125_col0, #T_af8bf_row128_col0, #T_af8bf_row192_col0, #T_af8bf_row197_col0, #T_af8bf_row206_col0, #T_af8bf_row216_col0, #T_af8bf_row240_col0, #T_af8bf_row249_col0, #T_af8bf_row285_col0, #T_af8bf_row314_col0, #T_af8bf_row349_col0, #T_af8bf_row398_col0, #T_af8bf_row415_col0, #T_af8bf_row417_col0 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_af8bf_row1_col1, #T_af8bf_row198_col1, #T_af8bf_row237_col1, #T_af8bf_row252_col1, #T_af8bf_row379_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.9%, #2a2aff 47.9%, #2a2aff 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row2_col0, #T_af8bf_row58_col0, #T_af8bf_row81_col0, #T_af8bf_row115_col0, #T_af8bf_row214_col0, #T_af8bf_row223_col0, #T_af8bf_row226_col0, #T_af8bf_row268_col0, #T_af8bf_row299_col0, #T_af8bf_row301_col0, #T_af8bf_row308_col0, #T_af8bf_row322_col0, #T_af8bf_row384_col0, #T_af8bf_row393_col0, #T_af8bf_row396_col0, #T_af8bf_row403_col0, #T_af8bf_row408_col0 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_af8bf_row2_col1, #T_af8bf_row31_col1, #T_af8bf_row104_col1, #T_af8bf_row115_col1, #T_af8bf_row151_col1, #T_af8bf_row285_col1, #T_af8bf_row291_col1, #T_af8bf_row302_col1, #T_af8bf_row349_col1, #T_af8bf_row365_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.8%, #3a3aff 49.8%, #3a3aff 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row3_col0, #T_af8bf_row66_col0, #T_af8bf_row91_col0, #T_af8bf_row152_col0, #T_af8bf_row156_col0, #T_af8bf_row166_col0, #T_af8bf_row186_col0, #T_af8bf_row190_col0, #T_af8bf_row224_col0, #T_af8bf_row263_col0, #T_af8bf_row286_col0, #T_af8bf_row305_col0, #T_af8bf_row320_col0, #T_af8bf_row368_col0, #T_af8bf_row381_col0, #T_af8bf_row383_col0, #T_af8bf_row397_col0, #T_af8bf_row400_col0 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_af8bf_row3_col1, #T_af8bf_row127_col1, #T_af8bf_row185_col1, #T_af8bf_row397_col1, #T_af8bf_row410_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #4a4aff 50.0%, #4a4aff 51.6%, transparent 51.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row4_col0, #T_af8bf_row6_col0, #T_af8bf_row18_col0, #T_af8bf_row34_col0, #T_af8bf_row76_col0, #T_af8bf_row83_col0, #T_af8bf_row102_col0, #T_af8bf_row193_col0, #T_af8bf_row208_col0, #T_af8bf_row213_col0, #T_af8bf_row251_col0, #T_af8bf_row345_col0, #T_af8bf_row372_col0, #T_af8bf_row378_col0 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_af8bf_row4_col1, #T_af8bf_row8_col1, #T_af8bf_row135_col1, #T_af8bf_row179_col1, #T_af8bf_row189_col1, #T_af8bf_row222_col1, #T_af8bf_row236_col1, #T_af8bf_row307_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #4242ff 50.0%, #4242ff 50.5%, transparent 50.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row5_col0, #T_af8bf_row25_col0, #T_af8bf_row64_col0, #T_af8bf_row80_col0, #T_af8bf_row85_col0, #T_af8bf_row100_col0, #T_af8bf_row129_col0, #T_af8bf_row178_col0, #T_af8bf_row188_col0, #T_af8bf_row200_col0, #T_af8bf_row235_col0, #T_af8bf_row238_col0, #T_af8bf_row246_col0, #T_af8bf_row262_col0, #T_af8bf_row284_col0, #T_af8bf_row292_col0, #T_af8bf_row306_col0, #T_af8bf_row316_col0, #T_af8bf_row331_col0, #T_af8bf_row336_col0, #T_af8bf_row348_col0, #T_af8bf_row362_col0, #T_af8bf_row370_col0, #T_af8bf_row385_col0, #T_af8bf_row414_col0, #T_af8bf_row418_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_af8bf_row5_col1, #T_af8bf_row23_col1, #T_af8bf_row63_col1, #T_af8bf_row138_col1, #T_af8bf_row241_col1, #T_af8bf_row292_col1, #T_af8bf_row384_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.6%, #3030ff 48.6%, #3030ff 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row6_col1, #T_af8bf_row78_col1, #T_af8bf_row169_col1, #T_af8bf_row199_col1, #T_af8bf_row223_col1, #T_af8bf_row326_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #4c4cff 50.0%, #4c4cff 51.8%, transparent 51.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row7_col0, #T_af8bf_row15_col0, #T_af8bf_row99_col0, #T_af8bf_row121_col0, #T_af8bf_row140_col0, #T_af8bf_row145_col0, #T_af8bf_row158_col0, #T_af8bf_row172_col0, #T_af8bf_row176_col0, #T_af8bf_row194_col0, #T_af8bf_row201_col0, #T_af8bf_row257_col0, #T_af8bf_row269_col0, #T_af8bf_row295_col0, #T_af8bf_row296_col0, #T_af8bf_row326_col0, #T_af8bf_row328_col0, #T_af8bf_row339_col0, #T_af8bf_row377_col0, #T_af8bf_row399_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_af8bf_row7_col1, #T_af8bf_row101_col1, #T_af8bf_row144_col1, #T_af8bf_row283_col1, #T_af8bf_row389_col1, #T_af8bf_row394_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.9%, #3232ff 48.9%, #3232ff 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row8_col0, #T_af8bf_row10_col0, #T_af8bf_row97_col0, #T_af8bf_row110_col0, #T_af8bf_row118_col0, #T_af8bf_row127_col0, #T_af8bf_row142_col0, #T_af8bf_row159_col0, #T_af8bf_row177_col0, #T_af8bf_row281_col0, #T_af8bf_row297_col0, #T_af8bf_row310_col0, #T_af8bf_row311_col0, #T_af8bf_row324_col0, #T_af8bf_row353_col0, #T_af8bf_row364_col0, #T_af8bf_row376_col0, #T_af8bf_row389_col0 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_af8bf_row9_col0, #T_af8bf_row33_col0, #T_af8bf_row56_col0, #T_af8bf_row59_col0, #T_af8bf_row74_col0, #T_af8bf_row78_col0, #T_af8bf_row86_col0, #T_af8bf_row89_col0, #T_af8bf_row101_col0, #T_af8bf_row105_col0, #T_af8bf_row112_col0, #T_af8bf_row134_col0, #T_af8bf_row138_col0, #T_af8bf_row153_col0, #T_af8bf_row199_col0, #T_af8bf_row211_col0, #T_af8bf_row218_col0, #T_af8bf_row219_col0, #T_af8bf_row228_col0, #T_af8bf_row239_col0, #T_af8bf_row265_col0, #T_af8bf_row274_col0, #T_af8bf_row294_col0, #T_af8bf_row325_col0, #T_af8bf_row340_col0, #T_af8bf_row352_col0, #T_af8bf_row392_col0, #T_af8bf_row407_col0 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_af8bf_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.3%, #2c2cff 48.3%, #2c2cff 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row10_col1, #T_af8bf_row91_col1, #T_af8bf_row160_col1, #T_af8bf_row180_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #5050ff 50.0%, #5050ff 52.2%, transparent 52.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row11_col0 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_af8bf_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, #8080ff 50.0%, #8080ff 57.6%, transparent 57.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row12_col0, #T_af8bf_row28_col0, #T_af8bf_row79_col0, #T_af8bf_row215_col0, #T_af8bf_row234_col0, #T_af8bf_row282_col0, #T_af8bf_row287_col0, #T_af8bf_row318_col0, #T_af8bf_row332_col0, #T_af8bf_row402_col0, #T_af8bf_row406_col0 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_af8bf_row12_col1, #T_af8bf_row195_col1, #T_af8bf_row265_col1, #T_af8bf_row369_col1, #T_af8bf_row391_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 47.2%, #2424ff 47.2%, #2424ff 50.0%, transparent 50.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_af8bf_row13_col0, #T_af8bf_row61_col0, #T_af8bf_row67_col0, #T_af8bf_row124_col0, #T_af8bf_row148_col0, #T_af8bf_row154_col0, #T_af8bf_row157_col0, #T_af8bf_row163_col0, #T_af8bf_row174_col0, #T_af8bf_row259_col0, #T_af8bf_row279_col0, #T_af8bf_row291_col0, #T_af8bf_row323
